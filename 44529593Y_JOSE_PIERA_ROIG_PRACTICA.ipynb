# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv(
    r'C:/Users/pepep/Desktop/dataset/Info_pais.csv',
    encoding='ISO-8859-1',
    delimiter=';',
    decimal=','
)

# %%
df.head()
# Out:
#             País   Poblacion  Renta per capita  Esperanza de vida
# 0  United States   325084756             59939               78.9
# 1          China  1421021791              8612               76.7
# 2          Japan   127502725             38214               84.5
# 3        Germany    82658409             44680               81.2
# 4          India  1338676785              1980               69.4

# %%
df_order = df.sort_values(
    'Poblacion',
    ascending=False
)

# %%
df_order.head()
# Out:
#              País   Poblacion  Renta per capita  Esperanza de vida
# 1           China  1421021791              8612               76.7
# 4           India  1338676785              1980               69.4
# 0   United States   325084756             59939               78.9
# 15      Indonesia   264650963              3837               71.5
# 38       Pakistan   207906209              1467               67.1

# %%
plt.scatter(
    df_order['Renta per capita'],
    df_order['Esperanza de vida']
);

# %%
plt.scatter(
    df_order['Renta per capita'],
    df_order['Esperanza de vida']
)

plt.title('Renta per Cápita vs Esperanza de vida')
plt.xlabel('Renta per cápita')
plt.ylabel('Esperanza de vida');

# %%
df_order['POblacion_normalizada'] = df_order['Poblacion']/(max(df_order['Poblacion'])/10000)

# %%
df_order.head()
# Out:
#              País   Poblacion  Renta per capita  Esperanza de vida  \
# 1           China  1421021791              8612               76.7
# 4           India  1338676785              1980               69.4
# 0   United States   325084756             59939               78.9
# 15      Indonesia   264650963              3837               71.5
# 38       Pakistan   207906209              1467               67.1
#
#     POblacion_normalizada  Poblacion_normalizada
# 1            10000.000000           10000.000000
# 4             9420.522567            9420.522567
# 0             2287.683117            2287.683117
# 15            1862.399047            1862.399047
# 38            1463.075446            1463.075446

# %%
plt.scatter(
    df_order['Renta per capita'],
    df_order['Esperanza de vida'],
    s=df_order['Poblacion_normalizada']
)

plt.title('Renta per Cápita vs Esperanza de vida')
plt.xlabel('Renta per cápita')
plt.ylabel('Esperanza de vida');

# %%
plt.scatter(
    df_order['Renta per capita'],
    df_order['Esperanza de vida'],
    s=df_order['Poblacion_normalizada']
)

plt.title('Renta per Cápita vs Esperanza de vida')
plt.xlabel('Renta per cápita')
plt.ylabel('Esperanza de vida')

fig=plt.gcf()
fig.set_size_inches(14.5,10);

# %%
plt.scatter(
    df_order['Renta per capita'],
    df_order['Esperanza de vida'],
    s=df_order['Poblacion_normalizada'],
    c=df_order['Poblacion_normalizada']
)

plt.title('Renta per Cápita vs Esperanza de vida')
plt.xlabel('Renta per cápita')
plt.ylabel('Esperanza de vida')

fig=plt.gcf()
fig.set_size_inches(14.5,10);

# %%
plt.scatter(
    df_order['Renta per capita'],
    df_order['Esperanza de vida'],
    s=df_order['Poblacion_normalizada'],
    c=df_order['Poblacion_normalizada']
)

plt.title('Renta per Cápita vs Esperanza de vida')
plt.xlabel('Renta per cápita')
plt.ylabel('Esperanza de vida')

fig=plt.gcf()
fig.set_size_inches(14.5,10);

df_order.reset_index(drop=True, inplace=True)

for i in range(0, 10):
    plt.annotate(
        df_order['País'][i],
        (df_order['Renta per capita'][i],df_order['Esperanza de vida'][i])
    )

# %%
plt.scatter(
    df_order['Renta per capita'],
    df_order['Esperanza de vida'],
    s=df_order['Poblacion_normalizada'],
    c=df_order['Poblacion_normalizada'],
    alpha=0.5
)

plt.title('Renta per Cápita vs Esperanza de vida')
plt.xlabel('Renta per cápita')
plt.ylabel('Esperanza de vida')

fig=plt.gcf()
fig.set_size_inches(14.5,10);

df_order.reset_index(drop=True, inplace=True)

for i in range(0, 10):
    plt.annotate(
        df_order['País'][i],
        (df_order['Renta per capita'][i],df_order['Esperanza de vida'][i])
    )

# %% [markdown]
# ## Conclusión final

# %% [markdown]
# podemos observar que hay cierta correlación entre la renta per cápita y la esperanza de vida, puesto que a mayor renta per cápita, mayor esperanza de vida, y viceversa. Podemos señalar también que salvo Japón y Estados Unidos, los países con mayor población tienden a estar en el rango inferior de Renta per cápita. China e India, con gran número de habitantes, tienen esperanzas de vida relativamente buenas, pero sus rentas per cápita (aún) son modestas. Sería interesante generar un vídeo que representase la evolución temporal de este gráfico.

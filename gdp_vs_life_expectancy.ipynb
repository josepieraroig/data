# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv(
    r'C:/Users/pepep/Desktop/dataset/Info_pais.csv',
    encoding='ISO-8859-1',
    delimiter=';',
    decimal=','
)

# %%
df_order = df.sort_values(
    'Poblacion',
    ascending=False
)

# %%
plt.scatter(
    df_order['Renta per capita'],
    df_order['Esperanza de vida']
);

# %%
plt.scatter(
    df_order['Renta per capita'],
    df_order['Esperanza de vida']
)

plt.title('Renta per Cápita vs Esperanza de vida')
plt.xlabel('Renta per cápita')
plt.ylabel('Esperanza de vida');

# %%
df_order['POblacion_normalizada'] = df_order['Poblacion']/(max(df_order['Poblacion'])/10000)

# %%
plt.scatter(
    df_order['Renta per capita'],
    df_order['Esperanza de vida'],
    s=df_order['Poblacion_normalizada'],
    c=df_order['Poblacion_normalizada'],
    alpha=0.5
)

plt.title('Renta per Cápita vs Esperanza de vida')
plt.xlabel('Renta per cápita')
plt.ylabel('Esperanza de vida')

fig=plt.gcf()
fig.set_size_inches(14.5,10);

df_order.reset_index(drop=True, inplace=True)

for i in range(0, 10):
    plt.annotate(
        df_order['País'][i],
        (df_order['Renta per capita'][i],df_order['Esperanza de vida'][i])
    )

# %% [markdown]
# ## Conclusión final / Final conclusion

# %% [markdown]
# we can see there is a correlation between life expectancy and gdp per capita, since a higher gdp per capita brings a higher life expectancy, and viceversa. We can point out that unless Japan and the US, countries with bigger population tend to be on the lower range od gdp per capita. China and India, greatly populated, have quite good life expectancies, but their gdp per capita are (still) modest. Next project will focus on creating an animated visualization with the chronological evolution of this representation, yearly.
#
# podemos observar que hay cierta correlación entre la renta per cápita y la esperanza de vida, puesto que a mayor renta per cápita, mayor esperanza de vida, y viceversa. Podemos señalar también que salvo Japón y Estados Unidos, los países con mayor población tienden a estar en el rango inferior de Renta per cápita. China e India, altamente pobladas, tienen esperanzas de vida relativamente buenas, pero sus rentas per cápita (aún) son modestas. El próximo proyecto tratará de generar un vídeo que represente la evolución temporal de este gráfico.
